# %%
# !git clone https://github.com/ultralytics/yolov5

# %%
# !pip install -r /content/yolov5/requirements.txt

# %%
# !unrar x /content/coco128.rar

# %%
# !python /content/yolov5/train.py --img 640 --batch 24 --epochs 3 --data coco128.yaml --weights /content/yolov5/runs/train/exp/weights/best.pt

# %%
# !unrar x /content/yolov5/ảnh mèo train yolo.rar

# %%
# !python /content/yolov5/detect.py  --source /content/ảnh mèo train yolo.rar
